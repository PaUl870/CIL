# %%
# %load_ext autoreload
# %autoreload 2

# %%
from helper import DataLoader
import models.SimpleGCN.SimpleGCN as SimpleGCN
import torch
from sklearn.metrics import root_mean_squared_error

# %%
DATAPATH = "../data"
RATING_DATA = DATAPATH + "/train_ratings.csv"
TBR_DATA = DATAPATH + "/train_tbr.csv"

# %%
data_manager = DataLoader.DataLoader(data_dir=DATAPATH)
train_df, valid_df = data_manager.load_and_split()

# %%
print(train_df)
# Out:
#          sid  pid  rating
# 0          0    1       5
# 1          0   13       4
# 2          0   22       5
# 3          0   26       4
# 4          0   62       4
# ...      ...  ...     ...
# 896738   957  337       3
# 896739  2218  232       5
# 896740  1146  255       4
# 896741  5758  519       4
# 896742  1062  437       5
#
# [896743 rows x 3 columns]

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
edge_t0_index, edge_t0_weights, edge_t1_index, edge_t1_weights = data_manager.get_graph_tensors(device)

# %%
# model = DualGraphGCN.DualGraphGCN(
#     num_users=data_manager.num_users,
#     num_items=data_manager.num_items,
#     embedding_dim=64,
#     num_layers=2,
#     dropout=0.5
# ).to(device)

# # model = SimpleGCN.SimpleGCN(
# #     num_users=data_manager.num_users,
# #     num_items=data_manager.num_items,
# #     embedding_dim=64,
# #     num_layers=1,
# #     dropout=0.3
# # ).to(device)

# criterion = torch.nn.MSELoss()
# def predict_ratings(sids, pids):
#     model.eval()
#     with torch.no_grad():
#         s_tensor = torch.tensor(sids, dtype=torch.long).to(device)
#         p_tensor = torch.tensor(pids, dtype=torch.long).to(device)
#         # Pass all 4 graph tensors
#         out, _, _ = model(s_tensor, p_tensor, 
#                    edge_t0_index, edge_t0_weights, 
#                    edge_t1_index, edge_t1_weights)        
#         # out, _, _ = model(s_tensor, p_tensor, 
#         #             edge_t0_index, edge_t0_weights)
#         return out.cpu().numpy()

# %%
# optimizer = torch.optim.Adam(
#     model.parameters(),
#     lr=1e-2,
# )

# %%
# EPOCHS = 5000
# LAMBDA_REG = 1e-4
# LAMBDA_WISHLIST = 0.5

# # --- 3. UPDATED TRAINING LOOP ---
# for epoch in range(EPOCHS):
#     model.train()
#     optimizer.zero_grad()
    
#     # Forward pass using both relation types
#     # We predict ratings for the users/items present in our t0 (ratings) edges
    
#     preds, (u_w, i_w), (u_init_r, i_init_r, u_init_w, i_init_w) = model(
#         edge_t0_index[0], edge_t0_index[1], 
#         edge_t0_index, edge_t0_weights,
#         edge_t1_index, edge_t1_weights
#     )    
#     pred_wishlist = (u_w[edge_t1_index[0]] * i_w[edge_t1_index[1]]).sum(-1)
#     # preds, u_init, i_init = model(
#     #     edge_t0_index[0],edge_t0_index[1], edge_t0_index, edge_t0_weights
#     # )
    
#     # Loss is still calculated against the actual ratings (weights_t0)
#     mse_loss = criterion(preds, edge_t0_weights * 5)
#     mse_loss_wishlist = criterion(pred_wishlist, edge_t1_weights * 1)
#     # l2_reg = (u_init.norm(2)**2 + i_init.norm(2)**2) / len(edge_t1_index[0])

#     loss = (
#         mse_loss 
#         + LAMBDA_WISHLIST * mse_loss_wishlist   # auxiliary
#         + LAMBDA_REG * sum(e.norm() for e in [u_init_r, i_init_r, u_init_w, i_init_w])  # regularization
#     )

    
#     loss.backward()
#     optimizer.step()
    
#     if epoch % 1 == 0:
#         val_preds = predict_ratings(valid_df["sid"].values, valid_df["pid"].values)
#         val_rmse = root_mean_squared_error(valid_df["rating"].values, val_preds)
#         print(f"Epoch {epoch} | Loss: {loss.item():.4f} | MSE: {mse_loss.item():.4f} | MSE Wishlist: {mse_loss_wishlist.item():.4f} | Val RMSE: {val_rmse:.4f}")

# %%
rating_model = SimpleGCN.SimpleGCN(data_manager.num_users, data_manager.num_items, embedding_dim=64, dropout=0.3, num_layers=1, layer_type="LightGCN")
rating_model = rating_model.to(device)
def rating_val():
    rating_model.eval()
    with torch.no_grad():
        # 1. Pass the IDs AND the graph tensors
        val_preds = rating_model.predict_ratings(
            valid_df["sid"].values, 
            valid_df["pid"].values,
            edge_t0_index,    # The graph structure
            edge_t0_weights   # The graph weights
        )
        
        # 2. Ensure variable names match (val_preds)
        return root_mean_squared_error(valid_df["rating"].values, val_preds * 5)

# %%
rating_model.fit(
    edge_index=edge_t0_index,
    weights=edge_t0_weights,
    log_every=50,
    lr=1e-2,
    val_fn=rating_val,
    targets=edge_t0_weights.float(),
    lambda_reg=1e-10,
    early_stop_patience=200,
    scheduler_patience=25
)
# Out:
# Epoch     0 | Loss: 0.1130 | Task: 0.1130 | Monitor: 1.6772 | LR: 1.00e-02 | No improvement: 0/200
# Epoch    50 | Loss: 0.0354 | Task: 0.0352 | Monitor: 0.9383 | LR: 1.00e-02 | No improvement: 2/200
# Epoch   100 | Loss: 0.0349 | Task: 0.0348 | Monitor: 0.9340 | LR: 1.00e-02 | No improvement: 1/200
# Epoch   150 | Loss: 0.0347 | Task: 0.0346 | Monitor: 0.9323 | LR: 1.00e-02 | No improvement: 0/200
# Epoch   200 | Loss: 0.0340 | Task: 0.0339 | Monitor: 0.9278 | LR: 1.00e-02 | No improvement: 4/200
# Epoch   250 | Loss: 0.0334 | Task: 0.0333 | Monitor: 0.9221 | LR: 1.00e-02 | No improvement: 1/200
# Epoch   300 | Loss: 0.0331 | Task: 0.0329 | Monitor: 0.9188 | LR: 1.00e-02 | No improvement: 2/200
# Epoch   350 | Loss: 0.0326 | Task: 0.0324 | Monitor: 0.9153 | LR: 1.00e-02 | No improvement: 1/200
# Epoch   400 | Loss: 0.0320 | Task: 0.0317 | Monitor: 0.9125 | LR: 1.00e-02 | No improvement: 11/200
# Epoch   450 | Loss: 0.0316 | Task: 0.0313 | Monitor: 0.9119 | LR: 2.50e-03 | No improvement: 61/200
# Epoch   500 | Loss: 0.0316 | Task: 0.0313 | Monitor: 0.9118 | LR: 1.25e-03 | No improvement: 34/200
# Epoch   550 | Loss: 0.0315 | Task: 0.0312 | Monitor: 0.9113 | LR: 6.25e-04 | No improvement: 3/200
# Epoch   600 | Loss: 0.0315 | Task: 0.0312 | Monitor: 0.9114 | LR: 1.56e-04 | No improvement: 53/200
# Epoch   650 | Loss: 0.0315 | Task: 0.0312 | Monitor: 0.9114 | LR: 3.91e-05 | No improvement: 103/200
# Epoch   700 | Loss: 0.0315 | Task: 0.0312 | Monitor: 0.9114 | LR: 9.77e-06 | No improvement: 153/200
# Early stopping at epoch 747 | Best monitor: 0.9114
# Restored best weights with monitor: 0.9114

# %%
import torch.nn.functional as F

# 1. Get the raw weights
raw_weights = rating_model.rating_weights.detach().cpu()

# 2. Apply Softmax (because that's how the model uses them in forward)
normalized_weights = F.softmax(raw_weights, dim=0)

# 3. Print
print("Learned Rating Importance:")
for i, weight in enumerate(normalized_weights):
    # i+1 assumes your ratings are 1, 2, 3, 4, 5
    print(f"Rating {i+1}: {raw_weights.item():.2%}")
# Out:
# Learned Rating Importance:
# Rating 1: 14.48%
# Rating 2: 17.24%
# Rating 3: 22.09%
# Rating 4: 22.95%
# Rating 5: 23.25%
